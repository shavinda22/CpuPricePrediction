# %%
# !pip install numpy
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip available: 22.3 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("data_cleaned.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'data_cleaned.csv' is the correct file path
data = pd.read_csv("data_cleaned.csv")

# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(data.isnull(), cmap="viridis", cbar=False)

plt.title('Null Values Heatmap')
plt.show()

# %%
data
# Out:
#                             name    price   socket         category  speed  \
# 0                     AMD 3015Ce     0.00      FT5  Mobile/Embedded   1200
# 1                      AMD 3015e     0.00  Unknown           Laptop   1200
# 2                      AMD 3020e     0.00  Unknown           Laptop   1200
# 3                      AMD 4700S     0.00  Unknown          Desktop   3600
# 4        AMD A10 Micro-6700T APU     0.00     FT3b           Laptop   1200
# ...                          ...      ...      ...              ...    ...
# 3947  Intel Xeon X7350 @ 2.93GHz   442.40      604           Server   2930
# 3948  Intel Xeon X7460 @ 2.66GHz   404.38   PGA604           Server   2660
# 3949  Intel Xeon X7550 @ 2.00GHz   200.00  LGA1567           Server   2000
# 3950  Intel Xeon X7560 @ 2.27GHz  2200.00  LGA1567           Server   2270
# 3951  Intel Xeon X7560 @ 2.27GHz  1100.00  LGA1567           Server   2270
#
#       cores
# 0         2
# 1         2
# 2         2
# 3         8
# ...

# %%
# !pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.1-py3-none-any.whl (294 kB)
# ...
#   Using cached matplotlib-3.8.2-cp311-cp311-win_amd64.whl (7.6 MB)
# ...
#   Using cached contourpy-1.2.0-cp311-cp311-win_amd64.whl (187 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#      ---------------------------------------- 2.2/2.2 MB 219.9 kB/s eta 0:00:00
# ...
#   Using cached kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
# ...
#      ---------------------------------------- 2.6/2.6 MB 204.0 kB/s eta 0:00:00
# ...
#   Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# ...
# [notice] A new release of pip available: 22.3 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'data_cleaned.csv' is the correct file path
data = pd.read_csv("data_cleaned.csv")

# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(data.isnull(), cmap="viridis", cbar=False)

plt.title('Null Values Heatmap')
plt.show()

# %%
data_new = data.replace(0, pd.NA).dropna()

# %%
data_new
# Out:
#                             name   price   socket category speed  cores
# 7          AMD A10 PRO-7850B APU  148.02     FM2+  Desktop  3700      2
# 8              AMD A10-4600M APU   78.02    FS1r2   Laptop  2300      2
# 11              AMD A10-5700 APU   59.95      FM2  Desktop  3400      2
# 13             AMD A10-5750M APU   94.02    FS1r2   Laptop  2500      4
# 15             AMD A10-5800B APU   44.99      FM2  Desktop  3800      2
# ...                          ...     ...      ...      ...   ...    ...
# 3947  Intel Xeon X7350 @ 2.93GHz   442.4      604   Server  2930      4
# 3948  Intel Xeon X7460 @ 2.66GHz  404.38   PGA604   Server  2660      6
# 3949  Intel Xeon X7550 @ 2.00GHz   200.0  LGA1567   Server  2000      8
# 3950  Intel Xeon X7560 @ 2.27GHz  2200.0  LGA1567   Server  2270      8
# 3951  Intel Xeon X7560 @ 2.27GHz  1100.0  LGA1567   Server  2270      8
#
# [2447 rows x 6 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'data_cleaned.csv' is the correct file path
data_new = pd.read_csv("data_cleaned.csv")

# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(data.isnull(), cmap="viridis", cbar=False)

plt.title('Null Values Heatmap')
plt.show()

# %%
data.isnull().sum()
# Out:
# name        0
# price       0
# socket      0
# category    0
# speed       0
# cores       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3952 entries, 0 to 3951
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      3952 non-null   object
#  1   price     3952 non-null   float64
#  2   socket    3952 non-null   object
#  3   category  3952 non-null   object
#  4   speed     3952 non-null   int64
#  5   cores     3952 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 185.4+ KB

# %%
data_new['name'].value_counts()
# Out:
# name
# Intel Xeon E5-4627 v2 @ 3.30GHz       3
# Intel Xeon E5-4657L v2 @ 2.40GHz      3
# Intel Xeon Platinum 8260 @ 2.40GHz    3
# AMD Opteron 6276                      3
# AMD Opteron 6328                      3
#                                      ..
# Intel Core i3-3240 @ 3.40GHz          1
# Intel Core i3-3225 @ 3.30GHz          1
# Intel Core i3-3220T @ 2.80GHz         1
# Intel Core i3-3220 @ 3.30GHz          1
# Intel Core i7-11700T @ 1.40GHz        1
# Name: count, Length: 2104, dtype: int64

# %%
data_new['name'] = data_new['name'].apply(lambda x:" ".join(x.split()[0:1]))

# %%
data_new['name'].value_counts()
# Out:
# name
# Intel    1810
# AMD       637
# Name: count, dtype: int64

# %%
data_new['socket'].value_counts()
# Out:
# socket
# FCLGA3647          157
# FCLGA1200           98
# LGA1366             97
# LGA1155             95
# SP3                 89
#                   ...
# AM1,FSB1             1
# FPGA946,FPGA947      1
# FCBGA2106            1
# LGA2066              1
# 604                  1
# Name: count, Length: 144, dtype: int64

# %%
def set_processor(name):
    if name == 'FCLGA3647' or name == 'FCLGA1200' or name == 'LGA1366' or name == 'LGA1155' or name == 'SP3':
        return name
    else:
        return 'Others'

data_new['socket'] = data_new['socket'].apply(set_processor)

# %%
data_new['socket'].value_counts()
# Out:
# socket
# Others       1911
# FCLGA3647     157
# FCLGA1200      98
# LGA1366        97
# LGA1155        95
# SP3            89
# Name: count, dtype: int64

# %%
data_new.shape
# Out:
# (2447, 6)

# %%
data_new['category'].value_counts()
# Out:
# category
# Server                      1064
# Desktop                      844
# Laptop                       417
# Unknown                       49
# Mobile/Embedded               25
# Desktop, Server               18
# Laptop, Mobile/Embedded       12
# Laptop, Server                 7
# Desktop, Laptop                4
# Server, Mobile/Embedded        4
# Desktop, Mobile/Embedded       3
# Name: count, dtype: int64

# %%
def set_processor(name):
    if name == 'Server' or name == 'Laptop' or name == 'Desktop' or name == 'Unknown'  or name == 'Desktop, Server'or name == 'Mobile/Embedded'or name == 'Laptop, Mobile/Embedded':
        return name
    else:
        return 'Others'

data_new['category'] = data_new['category'].apply(set_processor)

# %%
data_new['category'].value_counts()
# Out:
# category
# Server                     1064
# Desktop                     844
# Laptop                      417
# Unknown                      49
# Mobile/Embedded              25
# Desktop, Server              18
# Others                       18
# Laptop, Mobile/Embedded      12
# Name: count, dtype: int64

# %%
data_new
# Out:
#        name   price  socket category speed  cores
# 7       AMD  148.02  Others  Desktop  3700      2
# 8       AMD   78.02  Others   Laptop  2300      2
# 11      AMD   59.95  Others  Desktop  3400      2
# 13      AMD   94.02  Others   Laptop  2500      4
# 15      AMD   44.99  Others  Desktop  3800      2
# ...     ...     ...     ...      ...   ...    ...
# 3947  Intel   442.4  Others   Server  2930      4
# 3948  Intel  404.38  Others   Server  2660      6
# 3949  Intel   200.0  Others   Server  2000      8
# 3950  Intel  2200.0  Others   Server  2270      8
# 3951  Intel  1100.0  Others   Server  2270      8
#
# [2447 rows x 6 columns]

# %%
columns_to_encode = ['socket', 'category','name']
data_new = pd.get_dummies(data_new,columns=columns_to_encode)

# %%
data_new.shape
# Out:
# (2447, 19)

# %%
data_new.head()
# Out:
#      price speed  cores  socket_FCLGA1200  socket_FCLGA3647  socket_LGA1155  \
# 7   148.02  3700      2             False             False           False
# 8    78.02  2300      2             False             False           False
# 11   59.95  3400      2             False             False           False
# 13   94.02  2500      4             False             False           False
# 15   44.99  3800      2             False             False           False
#
#     socket_LGA1366  socket_Others  socket_SP3  category_Desktop  \
# 7            False           True       False              True
# 8            False           True       False             False
# 11           False           True       False              True
# 13           False           True       False             False
# 15           False           True       False              True
#
#     category_Desktop, Server  category_Laptop  \
# 7                      False            False
# ...

# %%
pip install sklearn
# Out:
# ...
#
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [15 lines of output]
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#     it would be great if you take some time to track which package uses
#     'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#   - as a last resort, set the environment variable
# ...

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
x=data_new.drop('price',axis=1)
y=data_new['price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.25)

# %%
x_train.shape,x_test.shape
# Out:
# ((1835, 18), (612, 18))

# %%
def model_acc(model):
    model.fit(x_train,y_train)
    acc=model.score(x_test,y_test)
    print(str(model)+ '-->' +str(acc))

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
model_acc(lr)
# Out:
# 0.9667313135673923

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
model_acc(dt)
# Out:
# 0.9369031500857129

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
model_acc(rf)
# Out:
# RandomForestRegressor()-->0.5431421429245755

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

def model_acc(model):
    # Assume you have your data loaded here (X and y)
    # Replace this with your actual data
    np.random.seed(42)
    X = np.random.rand(100, 1)
    y = 2 * X.squeeze() + 1 + 0.1 * np.random.randn(100)
    
    # Split the data into training and testing sets
    split_idx = int(0.8 * len(X))
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]
    
    model.fit(X_train, y_train)
    accuracy = model.score(X_test, y_test)
    
    return accuracy

# Initialize models
lr = LinearRegression()
dt = DecisionTreeRegressor()

# Get accuracy for each model
lr_accuracy = model_acc(lr)
dt_accuracy = model_acc(dt)

# Plotting
models = ['Linear Regression', 'Decision Tree']
accuracies = [lr_accuracy, dt_accuracy]

fig, ax = plt.subplots()
bar_width = 0.5
bars = ax.bar(models, accuracies, bar_width, color=['blue', 'green'])

# Add labels and title
ax.set_ylabel('Accuracy')
ax.set_title('Model Accuracy Comparison')

# Display the accuracy values on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Assuming 'X' and 'y' are your features and target variable
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Train the model on the training set
lr.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = lr.predict(X_test)

# Calculate testing accuracy metrics
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error (MSE): {mse}')
print(f'R-squared (R2): {r2}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 5
#       2 from sklearn.metrics import mean_squared_error, r2_score
#       4 # Assuming 'X' and 'y' are your features and target variable
# ----> 5 X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
#       7 # Train the model on the training set
#       8 lr.fit(X_train, y_train)
#
# File E:\5th\machineL\project\CPU Price Predector\model\env\Lib\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Assuming 'X' and 'y' are your features and target variable
X_train, X_test, y_train, y_test = train_test_split(, y, test_size=0.2, random_state=42)

# Initialize and train the Decision Tree model
dt_model = DecisionTreeRegressor(random_state=42)
dt_model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = dt_model.predict(X_test)

# Calculate testing accuracy metrics
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error (MSE): {mse}')
print(f'R-squared (R2): {r2}')
# Out:
# Mean Squared Error (MSE): 1419551.45997455
# R-squared (R2): 0.3028484486577636
